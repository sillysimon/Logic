// %% [markdown]
// # The Parrot and Penguin Problem
//
// In this notebook we are going to solve the following exercise using the constraint solver `Z3`.
//    * A Japanese deli offers both [penguins](https://www.discovermagazine.com/health/hearty-penguin-steaks-the-old-school-explorers-salve-for-scurvy)
//      and [parrots](http://fancytoast.blogspot.com/2007/04/parrot-three-ways.html).
//    * A parrot and a penguin together cost 666 bucks.
//    * The penguin costs 600 bucks more than the parrot.
//
// What is the price of the parrot? You may assume that the prizes of these delicacies are integer valued.

// %% [markdown]
// First, we initialize the `z3-solver` library.

// %%
import { init } from 'z3-solver';
const  { Context } = await init();
const ctx = Context("main");

// %% [markdown]
// We declare our constraint variables for the prices. Since the problem states the prices are integer valued, we use `ctx.Int.const(name)`.

// %%
"your code here"

// %% [markdown]
// Next, we create the *solver* object.

// %%
"your code here"

// %% [markdown]
// Now we add our constraints to the solver using `.add()`.
//
//
// We translate these into Z3's syntax using the method `.eq()` for equality and `.add()` for addition.

// %%
"your code here"

// %% [markdown]
// We check if the constraints are satisfiable.

// %%
"your code here"

// %% [markdown]
// We extract the model to find the specific integer values that satisfy our conditions.

// %%
"your code here"

// %% [markdown]
// Finally, we extract the numerical values using `eval`, convert the Z3 AST objects to strings, and parse them into native JavaScript integers to output the answer.

// %%
const priceParrot  = "your code here"
const pricePenguin = "your code here"

// %%
console.log(`The price of the parrot is ${priceParrot} bucks.`);
console.log(`The price of the penguin is ${pricePenguin} bucks.`);
console.log(`\nVerification:`);
console.log(`Parrot + Penguin = ${priceParrot} + ${pricePenguin} = ${priceParrot + pricePenguin}`);
console.log(`Penguin is 600 more than Parrot: ${priceParrot} + 600 = ${pricePenguin}`);
